# %%
import pandas as pd
import sys
import matplotlib.pyplot as plt
pd.options.display.max_columns=1000
pd.set_option('display.max_colwidth', -1)
sys.path.insert(0, "C:\\Users\\vberlia\\Documents\\machine_learning")

# %%
from machineLearning.dataSummary import DataSummary
from machineLearning.visualizations import Visualization
from machineLearning.missingValues import MissingValue
from machineLearning.missingValues import CustomCategoryImputer
from machineLearning.missingValues import CustomQuantitativeImputer
from machineLearning.missingValues import CustomDummifier
from machineLearning.featureCreation import CustomCutter
from machineLearning.missingValues import CustomEncoderManyCols
from machineLearning.models import Model
from machineLearning.modelInputs import KNNInputs
from machineLearning.pipelines import Pipelines
from machineLearning.misc import Misc
from sklearn.pipeline import Pipeline
import numpy as np

# %%
X = pd.DataFrame({'city':['tokyo', None, 'london', 'seattle', 'sanfrancisco', 'tokyo'],'boolean':['yes', 'no', None, 'no', 'no', 'yes'],'ordinal_column':['somewhat like', 'like','somewhat like', 'like', 'somewhat like', 'dislike'],'quantitative_column':[1, 11, -.5, 10, None,20]})

# %%
X
# Out:
#   boolean          city ordinal_column  quantitative_column
# 0  yes     tokyo         somewhat like  1.0
# 1  no      None          like           11.0
# 2  None    london        somewhat like -0.5
# 3  no      seattle       like           10.0
# 4  no      sanfrancisco  somewhat like NaN
# 5  yes     tokyo         dislike        20.0

# %%
DataSummary.returnSummaryDataFrame(X).transpose()
# Out:
#                     col_type count_unique  \
# boolean              object   2
# city                 object   4
# ordinal_column       object   3
# quantitative_column  float64  5
#
#                                                         unique_values  \
# boolean              ['yes' 'no' None]
# city                 ['tokyo' None 'london' 'seattle' 'sanfrancisco']
# ordinal_column       ['somewhat like' 'like' 'dislike']
# quantitative_column  [1.0 11.0 -0.5 10.0 nan 20.0]
#
#                     missing_count count mean      std  min  25% 50%(median)  \
# boolean              1             NaN   NaN  NaN      NaN  NaN  NaN
# city                 1             NaN   NaN  NaN      NaN  NaN  NaN
# ordinal_column       0             NaN   NaN  NaN      NaN  NaN  NaN
# quantitative_column  1             5     8.3  8.33367 -0.5  1    10
#
#                      75%  max           mode
# boolean              NaN  NaN  no
# city                 NaN  NaN  tokyo
# ordinal_column       NaN  NaN  somewhat like
# quantitative_column  11   20   NaN

# %%
cci = CustomCategoryImputer(cols=['city', 'boolean','ordinal_column'])
cqi = CustomQuantitativeImputer(cols=['quantitative_column'],strategy='mean')
dummyFier=CustomDummifier(cols=['city','boolean'])
encoder=CustomEncoderManyCols({'ordinal_column':['dislike', 'somewhat like', 'like']})
cut_col_quan=CustomCutter(bins=3,col='quantitative_column',labels=False)

# %%
column
0	yes	tokyo	somewhat like	1.0
1	no	None	like	11.0
2	None	london	somewhat like	-0.5
3	no	seattle	like	10.0
4	no	sanfrancisco	somewhat like	NaN
5	yes	tokyo	dislike	20.0X
# Out:
#   boolean          city ordinal_column  quantitative_column
# 0  yes     tokyo         somewhat like  1.0
# 1  no      None          like           11.0
# 2  None    london        somewhat like -0.5
# 3  no      seattle       like           10.0
# 4  no      sanfrancisco  somewhat like NaN
# 5  yes     tokyo         dislike        20.0

# %%
imputer = Pipeline([('quant_imputer', cqi), ('category_imputer', cci),('category_dummifier',dummyFier),('enoder',encoder),('cut_col',cut_col_quan)])
imputer.fit_transform(X)
# Out:
#    ordinal_column  quantitative_column  city_london  city_sanfrancisco  \
# 0  1               1.0                  0            0
# 1  2               11.0                 0            0
# 2  1              -0.5                  1            0
# 3  2               10.0                 0            0
# 4  1               8.3                  0            1
# 5  0               20.0                 0            0
#
#    city_seattle  city_tokyo  boolean_no  boolean_yes  \
# 0  0             1           0           1
# 1  0             1           1           0
# 2  0             0           1           0
# 3  1             0           1           0
# 4  0             0           1           0
# 5  0             1           0           1
#
#    quantitative_column_binned
# 0  0
# 1  1
# 2  0
# 3  1
# 4  1
# 5  2

# %%
cut_col_quan.labels
# Out:
# False
